# %%
from keras.models import load_model
import segmentation_models as sm
import glob
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf

# %%
my_model=load_model('shadow.hdf5',custom_objects={'iou_score':sm.metrics.IOUScore})

# %%
X=np.load('imgs.npy')
Y=np.load('masks.npy')
Y = np.expand_dims(Y, axis=3)

# %%
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
new_image = tf.expand_dims(X[556],0)
new_image.shape
test_pred=my_model.predict(new_image)
# Out:
# 1/1 [==============================] - 0s 128ms/step

# %%
test_pred[0].shape
# Out:
# (256, 256, 1)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(X[556], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(Y[556])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_pred[0])
plt.show()

# %%
np.unique(test_pred1[0])
# Out:
# array([1.], dtype=float32)
